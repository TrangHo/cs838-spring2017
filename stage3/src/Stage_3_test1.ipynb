# %%
import sys
import os
import py_entitymatching as em
print('magellan version:' + em.__version__)
import re
import csv
import pandas as pd

from cleaner import Cleaner
from constants import csv_headers
# Out:
# magellan version:0.1.0

# %%
working_dir = os.path.dirname(os.getcwd())
path_to_csv_dir = working_dir + os.sep + 'csv_files'+ os.sep

# %% [markdown]
# # STEP 1 - PRE-PROCESSING DATA
#
# In this stage, we need to preprocess data before applying Megellan. This is because our datasets (especially the AOM dataset) are quite dirty, and therefore adversely affecting Megellan's blocking and matching functions. For example, states can take any value of "CA", "California", or "CA - California".
#
# In this step, we will clean the following variables:
# * Country name (e.g. Whed data has 2 Belgiums: (1) Belgium - French Community and (2) Belgium - Flemish Community)
# * State name
# * City name
# * Affiliation name
# * Email server domain (we will only capture the university information from the email server domain - if there is any)

# %% [markdown]
# ### 1.A. Clean AOM data

# %%
aom_cleaner = Cleaner(path_to_csv_dir + '_aom.csv', csv_headers.AOM_INDEX, csv_headers.AOM)

aom_cleaner.clean_affiliation('a_name')
aom_cleaner.clean_email_server('a_email_server')
aom_cleaner.clean_city('a_city')
aom_cleaner.clean_country('a_country')
aom_cleaner.clean_states('a_prov', 'a_country')

aom_cleaner.to_csv(path_to_csv_dir + '_aom_cleaned.csv')
aom_cleaner.data.head(n=3)
# Out:
#                           a_name            a_city         a_prov  \
# person_id
# 1             academy management  briarcliff manor       new york
# 4          nor astern university            boston  massachusetts
# 5               skidmore college  saratoga springs       new york
#
#                a_country a_email_server
# person_id
# 1          united states            aom
# 4          united states          gmail
# 5          united states       skidmore

# %% [markdown]
# ### 1.B. Clean WHED data

# %%
whed_cleaner = Cleaner(path_to_csv_dir + '_whed.csv', csv_headers.WHED_INDEX, csv_headers.WHED, encoding = 'ISO-8859-1')

whed_cleaner.clean_affiliation('a_name')
whed_cleaner.clean_city('a_city')
whed_cleaner.clean_country('a_country')

whed_cleaner.to_csv(path_to_csv_dir + '_whed_cleaned.csv')
whed_cleaner.data.head(n=3)
# Out:
#                                                 a_name    a_country  \
# a_id
# 2               pampanga state agricultural university  philippines
# 4     les roches international school hotel management  switzerland
# 6             dharma gate budapest buddhist university      hungary
#
#                     a_city                a_prov                     a_web
# a_id
# 2                 magalang              Pampanga     http://www.pac.edu.ph
# 4     bluche crans montana  Bluche-Crans-Montana  http://www.lesroches.edu
# 6                 budapest                   NaN        http://www.tkbf.eu

# %% [markdown]
# # STEP 2 - MAGELLAN - BLOCKING

# %%
AOM = em.read_csv_metadata(path_to_csv_dir + '_aom_cleaned.csv', key = csv_headers.AOM_INDEX)
print(em.get_key(AOM))

WHED = em.read_csv_metadata(path_to_csv_dir + '_whed_cleaned.csv', key = csv_headers.WHED_INDEX)
print(em.get_key(WHED))
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# person_id
# a_id

# %%
# building inverted index based on B
sample_WHED, sample_AOM = em.down_sample(WHED, AOM, size=2000, y_param=10)
print(len(sample_WHED))
print(len(sample_AOM))
em.show_properties(sample_WHED)
em.show_properties(sample_AOM)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:12 | ETA: 00:00:10 | ETA: 00:00:10 | ETA: 00:00:09 | ETA: 00:00:09 | ETA: 00:00:08 | ETA: 00:00:08 | ETA: 00:00:07 | ETA: 00:00:07 | ETA: 00:00:07 | ETA: 00:00:06 | ETA: 00:00:06 | ETA: 00:00:06 | ETA: 00:00:05 | ETA: 00:00:05 | ETA: 00:00:04 | ETA: 00:00:04 | ETA: 00:00:04 | ETA: 00:00:03 | ETA: 00:00:03 | ETA: 00:00:03 | ETA: 00:00:02 | ETA: 00:00:02 | ETA: 00:00:02 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00
# 8872
# 2000
# id: 4633726312
# key: a_id
# id: 4633726536
# key: person_id
# Total time elapsed: 00:00:10

# %%
sample_WHED.head(n=5)
# Out:
#         a_id                                  a_name    a_country     a_city  \
# 16384  21848         zhongyuan university technology        china  zhengzhou
# 0          2  pampanga state agricultural university  philippines   magalang
# 16386  21850   zhytomyr state ivan franko university      ukraine    zytomyr
# 16387  21851                     ziauddin university     pakistan    karachi
# 16385  21849               zhoukou normal university        china    zhoukou
#
#                a_prov                     a_web
# 16384  Henan Province    http://www.zzti.edu.cn
# 0            Pampanga     http://www.pac.edu.ph
# 16386  Zytomyr Region  http://www.academy.zt.ua
# 16387           Sindh      http://www.zu.edu.pk
# 16385           Henan   http://www.zknu.edu.cn/

# %%
sample_AOM.head(n=5)
# Out:
#       person_id                                                       a_name  \
# 4783      35712                                      renmin university china
# 9311      59456  north china university water conservancy and electric power
# 3209      20917                                           university chicago
# 5217      39424                             university complutense de madrid
# 7451      55302                                  washington state university
#
#          a_city      a_prov      a_country a_email_server
# 4783    beijing         NaN          china            ruc
# 9311  zhengzhou          he          china            126
# 3209    chicago    illinois  united states   chicagobooth
# 5217     madrid         NaN          spain            ucm
# 7451    pullman  washington  united states            wsu

# %%
def match_country_prov(ltuple, rtuple):
#   return True  - if the intention is to drop the pair
#          False - if the intention is to keep the tuple pair
    l_country = ltuple['a_country']
    r_country = rtuple['a_country']
    l_prov = ltuple['a_prov']
    r_prov = rtuple['a_prov']
    
    if l_country != r_country:
        return True
    elif l_country == "united states":
        if l_prov != r_prov:
            return True
        else:
            return False
    else:
        return False

def match_domain(ltuple, rtuple):
    l_web = ltuple['a_web']
    r_email = rtuple['a_email_server']
    if str(r_email) in str(l_web):
        return False
    else:
        return True

    
def match_overlap(ltuple, rtuple):
    l_tokens = em.tok_wspace(ltuple['a_name'])
    r_tokens = em.tok_wspace(rtuple['a_name'])
    print(l_tokens)
    print(r_tokens)    
    
    if len(l_tokens) > 1 and len(r_tokens) > 1:
        if "university" in l_tokens:
            l_tokens.remove("university") 
        if "university" in r_tokens:
            r_tokens.remove("university") 
        return em.overlap_coeff(l_tokens, r_tokens) == 0
    else:
        return False
    
def match_combined(ltuple, rtuple):
    if match_country_prov(ltuple, rtuple):
        return True
    elif match_domain(ltuple, rtuple):        
        return match_overlap(ltuple, rtuple)
    else:
        return False
    
def blocking(A, B):
    bb = em.BlackBoxBlocker()
    bb.set_black_box_function(match_combined)
    C = bb.block_tables(A, B, l_output_attrs=['a_name','a_country','a_city','a_prov','a_web'], r_output_attrs=['a_name','a_country','a_city','a_prov','a_email_server'] )
    return C

C = blocking(sample_WHED, sample_AOM)
# Out:
# 0%                          100%
# [                              ]
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['north', 'china', 'university', 'water', 'conservancy', 'and', 'electric', 'power']
# ['zhongyuan', 'university', 'technology']
# ['huazhong', 'university', 'science', 'technology']
# ['zhongyuan', 'university', 'technology']
# ['university', 'hong', 'kong']
# ['zhongyuan', 'university', 'technology']
# ['ceibs']
# ['zhongyuan', 'university', 'technology']
# ['sichuan', 'university']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['gsm', 'peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['chinese', 'university', 'hong', 'kong']
# ['zhongyuan', 'university', 'technology']
# ['jilin', 'university']
# ['zhongyuan', 'university', 'technology']
# ['beijing', 'normal', 'university']
# ['zhongyuan', 'university', 'technology']
# ['shandong', 'university', '/', 'ludong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['northwest', 'university']
# ['zhongyuan', 'university', 'technology']
# ['tsinghua', 'university']
# ['zhongyuan', 'university', 'technology']
# ['southwestern', 'university', 'finance', 'economics']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['shanghai', 'international', 'studies', 'university']
# ['zhongyuan', 'university', 'technology']
# ['tsinghua', 'university']
# ['zhongyuan', 'university', 'technology']
# ['nanjing', 'university']
# ['zhongyuan', 'university', 'technology']
# ['nankai', 'university']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['nottingham', 'university', 'business', 'school', 'china']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['national', 'university', 'defense', 'technology']
# ['zhongyuan', 'university', 'technology']
# ['east', 'china', 'university', 'science', 'andtechnology']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['remin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['heng', 'dao', 'firms', 'management', 'consulting', 'co.ltd']
# ['zhongyuan', 'university', 'technology']
# ['guangdong', 'university', 'technology']
# ['zhongyuan', 'university', 'technology']
# ['china', 'europe', 'international', 'business', 'school']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['lingnan', 'university', 'college', 'sun', 'yat', 'sen', 'university']
# ['zhongyuan', 'university', 'technology']
# ['shanghai', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['wuhan', 'university']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['xiamen', 'university']
# ['zhongyuan', 'university', 'technology']
# ['shanghai', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['zhejiang', 'university']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'liverpool', 'university']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['hong', 'kong', 'university', 'science', 'and', 'technology']
# ['zhongyuan', 'university', 'technology']
# ['gsm', 'peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['nanjing', 'university']
# ['zhongyuan', 'university', 'technology']
# ['guangdong', 'university', 'technology']
# ['zhongyuan', 'university', 'technology']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhongyuan', 'university', 'technology']
# ['ceibs']
# ['zhongyuan', 'university', 'technology']
# ['renmin', 'university', 'china']
# ['zhongyuan', 'university', 'technology']
# ['school', 'management', 'xiamen', 'university']
# ['zhongyuan', 'university', 'technology']
# ['ucd']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['beijing', 'normal', 'university']
# ['zhongyuan', 'university', 'technology']
# ['peking', 'university']
# ['zhongyuan', 'university', 'technology']
# ['sun', 'yat', 'sen', 'university']
# ['zhongyuan', 'university', 'technology']
# ['university', 'nottingham', 'ningbo', 'china']
# ['pampanga', 'state', 'agricultural', 'university']
# ['de', 'la', 'salle', 'university']
# ['pampanga', 'state', 'agricultural', 'university']
# ['university', 'philippines']
# ['pampanga', 'state', 'agricultural', 'university']
# ['university', 'philippines']
# ['ziauddin', 'university']
# ['international', 'islamic', 'university']
# ['ziauddin', 'university']
# ['university', 'central', 'punjab']
# ['ziauddin', 'university']
# ['iba', 'karachi']
# ['ziauddin', 'university']
# ['superior', 'university']
# ['ziauddin', 'university']
# ['superior', 'university']
# ['ziauddin', 'university']
# ['shah', 'abdul', 'latif', 'university']
# ['ziauddin', 'university']
# ['university', 'central', 'punjab']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['north', 'china', 'university', 'water', 'conservancy', 'and', 'electric', 'power']
# ['zhoukou', 'normal', 'university']
# ['huazhong', 'university', 'science', 'technology']
# ['zhoukou', 'normal', 'university']
# ['university', 'hong', 'kong']
# ['zhoukou', 'normal', 'university']
# ['ceibs']
# ['zhoukou', 'normal', 'university']
# ['sichuan', 'university']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['gsm', 'peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['chinese', 'university', 'hong', 'kong']
# ['zhoukou', 'normal', 'university']
# ['jilin', 'university']
# ['zhoukou', 'normal', 'university']
# ['beijing', 'normal', 'university']
# ['zhoukou', 'normal', 'university']
# ['shandong', 'university', '/', 'ludong', 'university']
# ['zhoukou', 'normal', 'university']
# ['northwest', 'university']
# ['zhoukou', 'normal', 'university']
# ['tsinghua', 'university']
# ['zhoukou', 'normal', 'university']
# ['southwestern', 'university', 'finance', 'economics']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['shanghai', 'international', 'studies', 'university']
# ['zhoukou', 'normal', 'university']
# ['tsinghua', 'university']
# ['zhoukou', 'normal', 'university']
# ['nanjing', 'university']
# ['zhoukou', 'normal', 'university']
# ['nankai', 'university']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['nottingham', 'university', 'business', 'school', 'china']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['national', 'university', 'defense', 'technology']
# ['zhoukou', 'normal', 'university']
# ['east', 'china', 'university', 'science', 'andtechnology']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['remin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['heng', 'dao', 'firms', 'management', 'consulting', 'co.ltd']
# ['zhoukou', 'normal', 'university']
# ['guangdong', 'university', 'technology']
# ['zhoukou', 'normal', 'university']
# ['china', 'europe', 'international', 'business', 'school']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['lingnan', 'university', 'college', 'sun', 'yat', 'sen', 'university']
# ['zhoukou', 'normal', 'university']
# ['shanghai', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['wuhan', 'university']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['xiamen', 'university']
# ['zhoukou', 'normal', 'university']
# ['shanghai', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['zhejiang', 'university']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'liverpool', 'university']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['hong', 'kong', 'university', 'science', 'and', 'technology']
# ['zhoukou', 'normal', 'university']
# ['gsm', 'peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['nanjing', 'university']
# ['zhoukou', 'normal', 'university']
# ['guangdong', 'university', 'technology']
# ['zhoukou', 'normal', 'university']
# ['xi', 'an', 'jiaotong', 'university']
# ['zhoukou', 'normal', 'university']
# ['ceibs']
# ['zhoukou', 'normal', 'university']
# ['renmin', 'university', 'china']
# ['zhoukou', 'normal', 'university']
# ['school', 'management', 'xiamen', 'university']
# ['zhoukou', 'normal', 'university']
# ['ucd']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['beijing', 'normal', 'university']
# ['zhoukou', 'normal', 'university']
# ['peking', 'university']
# ['zhoukou', 'normal', 'university']
# ['sun', 'yat', 'sen', 'university']
# ['zhoukou', 'normal', 'university']
# ['university', 'nottingham', 'ningbo', 'china']
# ['aalto', 'university']
# ['hanken', 'school', 'economics']
# ['aalto', 'university']
# ['hanken', 'school', 'economics']
# ['aalto', 'university']
# ['university', 'oulu', 'business', 'school']
# ['aalto', 'university']
# ['lappeenranta', 'university', 'technology']
# ['aalto', 'university']
# ['aalto', 'university']
# ['aalto', 'university']
# ['lappeenranta', 'university', 'technology']
# ['aalto', 'university']
# ['aalto', 'university']
# ['aalto', 'university']
# ['university', 'eastern', 'finland']
# ['aalto', 'university']
# ['university', 'turku']
# ['aalto', 'university']
# ['university', 'vaasa']
# ['aalto', 'university']
# ['jyvaskyla', 'university']
# ['aalto', 'university']
# ['university', 'oulu']
# ['aalto', 'university']
# ['hanken', 'school', 'economics']
# ['aalto', 'university']
# ['university', 'helsinki']
# ['aalto', 'university']
# ['university', 'vaasa']
# ['aalto', 'university']
# ['university', 'oulu']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['university', 'sou', 'rn', 'denmark']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['aarhus', 'university']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['kpmg']
# ['aarhus', 'university']
# ['development', 'consultants']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['resonans']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['aarhus', 'university']
# ['copenhagen', 'business', 'school']
# ['zonguldak', 'karaelmas', 'university']
# ['bahcesehir', 'university']
# ['zonguldak', 'karaelmas', 'university']
# ['istanbul', 'bilgi', 'university']
# ['zonguldak', 'karaelmas', 'university']
# ['istanbul', 'arel', 'university']
# ['zonguldak', 'karaelmas', 'university']
# ['ege', 'university', 'science', 'and', 'technology', 'centre']
# ['zonguldak', 'karaelmas', 'university']
# ['toros', 'university']
# ['zonguldak', 'karaelmas', 'university']
# ['sabanci', 'university']
# ['abant', 'izzet', 'baysal', 'university']
# ['bahcesehir', 'university']
# ['abant', 'izzet', 'baysal', 'university']
# ['istanbul', 'bilgi', 'university']
# ['abant', 'izzet', 'baysal', 'university']
# ['istanbul', 'arel', 'university']
# ['abant', 'izzet', 'baysal', 'university']
# ['ege', 'university', 'science', 'and', 'technology', 'centre']
# ['abant', 'izzet', 'baysal', 'university']
# ['toros', 'university']
# ['abant', 'izzet', 'baysal', 'university']
# ['sabanci', 'university']
# ['abe', 'international', 'business', 'college']
# ['de', 'la', 'salle', 'university']
# ['abe', 'international', 'business', 'college']
# ['university', 'philippines']
# ['abe', 'international', 'business', 'college']
# ['university', 'philippines']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['north', 'china', 'university', 'water', 'conservancy', 'and', 'electric', 'power']
# ['zunyi', 'normal', 'college']
# ['huazhong', 'university', 'science', 'technology']
# ['zunyi', 'normal', 'college']
# ['university', 'hong', 'kong']
# ['zunyi', 'normal', 'college']
# ['ceibs']
# ['zunyi', 'normal', 'college']
# ['sichuan', 'university']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['gsm', 'peking', 'university']
# ['zunyi', 'normal', 'college']
# ['chinese', 'university', 'hong', 'kong']
# ['zunyi', 'normal', 'college']
# ['jilin', 'university']
# ['zunyi', 'normal', 'college']
# ['beijing', 'normal', 'university']
# ['zunyi', 'normal', 'college']
# ['shandong', 'university', '/', 'ludong', 'university']
# ['zunyi', 'normal', 'college']
# ['northwest', 'university']
# ['zunyi', 'normal', 'college']
# ['tsinghua', 'university']
# ['zunyi', 'normal', 'college']
# ['southwestern', 'university', 'finance', 'economics']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['shanghai', 'international', 'studies', 'university']
# ['zunyi', 'normal', 'college']
# ['tsinghua', 'university']
# ['zunyi', 'normal', 'college']
# ['nanjing', 'university']
# ['zunyi', 'normal', 'college']
# ['nankai', 'university']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['nottingham', 'university', 'business', 'school', 'china']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['national', 'university', 'defense', 'technology']
# ['zunyi', 'normal', 'college']
# ['east', 'china', 'university', 'science', 'andtechnology']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['remin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['heng', 'dao', 'firms', 'management', 'consulting', 'co.ltd']
# ['zunyi', 'normal', 'college']
# ['guangdong', 'university', 'technology']
# ['zunyi', 'normal', 'college']
# ['china', 'europe', 'international', 'business', 'school']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['lingnan', 'university', 'college', 'sun', 'yat', 'sen', 'university']
# ['zunyi', 'normal', 'college']
# ['shanghai', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['wuhan', 'university']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['xiamen', 'university']
# ['zunyi', 'normal', 'college']
# ['shanghai', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['zhejiang', 'university']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'liverpool', 'university']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['hong', 'kong', 'university', 'science', 'and', 'technology']
# ['zunyi', 'normal', 'college']
# ['gsm', 'peking', 'university']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['nanjing', 'university']
# ['zunyi', 'normal', 'college']
# ['guangdong', 'university', 'technology']
# ['zunyi', 'normal', 'college']
# ['xi', 'an', 'jiaotong', 'university']
# ['zunyi', 'normal', 'college']
# ['ceibs']
# ['zunyi', 'normal', 'college']
# ['renmin', 'university', 'china']
# ['zunyi', 'normal', 'college']
# ['school', 'management', 'xiamen', 'university']
# ['zunyi', 'normal', 'college']
# ['ucd']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['beijing', 'normal', 'university']
# ['zunyi', 'normal', 'college']
# ['peking', 'university']
# ['zunyi', 'normal', 'college']
# ['sun', 'yat', 'sen', 'university']
# ['zunyi', 'normal', 'college']
# ['university', 'nottingham', 'ningbo', 'china']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['imd']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'geneva']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'lausanne', 'hec', 'lausanne']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['ecole', 'hoteliere', 'de', 'lausanne']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['ecole', 'hoteliere', 'de', 'lausanne']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['eth', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'lugano']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'lausanne']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'lugano']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'lausanne']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['eth', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['haute', 'ecole', 'de', 'gestion', 'fribourg']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['eth', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['eth', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'st.', 'gallen']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['imd']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'zurich']
# ['university', 'applied', 'sciences', 'zurcher', 'fachhochschule']
# ['university', 'geneva']
# ['abia', 'state', 'university']
# ['lagos', 'business', 'school']
# ['sifa', 'university']
# ['bahcesehir', 'university']
# ['sifa', 'university']
# ['istanbul', 'bilgi', 'university']
# ['sifa', 'university']
# ['istanbul', 'arel', 'university']
# ['sifa', 'university']
# ['ege', 'university', 'science', 'and', 'technology', 'centre']
# ['sifa', 'university']
# ['toros', 'university']
# ['sifa', 'university']
# ['sabanci', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['hanken', 'school', 'economics']
# ['abo', 'akademi', 'university']
# ['hanken', 'school', 'economics']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'oulu', 'business', 'school']
# ['abo', 'akademi', 'university']
# ['lappeenranta', 'university', 'technology']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['lappeenranta', 'university', 'technology']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'eastern', 'finland']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'turku']
# ['abo', 'akademi', 'university']
# ['university', 'vaasa']
# ['abo', 'akademi', 'university']
# ['jyvaskyla', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'oulu']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['hanken', 'school', 'economics']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'helsinki']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'vaasa']
# ['abo', 'akademi', 'university']
# ['aalto', 'university']
# ['abo', 'akademi', 'university']
# ['university', 'oulu']
# ['abu', 'dhabi', 'university']
# ['insead']
# ['abu', 'dhabi', 'university']
# ['american', 'university', 'sharjah', '/', 'ese', 'business', 'school', 'chile']
# ['abu', 'dhabi', 'university']
# ['zayed', 'university']
# ['abu', 'dhabi', 'university']
# ['insead']
# ['abu', 'dhabi', 'university']
# ['university', 'wollongong', 'dubai']
# ['abu', 'dhabi', 'university']
# ['british', 'university', 'dubai']
# ['abu', 'dhabi', 'university']
# ['zayed', 'university']
# ['abubakar', 'computer', 'learning', 'center', 'foundation']
# ['de', 'la', 'salle', 'university']
# ['abubakar', 'computer', 'learning', 'center', 'foundation']
# ['university', 'philippines']
# ['abubakar', 'computer', 'learning', 'center', 'foundation']
# ['university', 'philippines']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['meiji', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['meiji', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['kyoto', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['university', 'tsukuba']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['international', 'university', 'japan']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['meiji', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['meiji', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['kwansei', 'gakuin', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['kyoto', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['chuo', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['meiji', 'university']
# ['graduate', 'school', 'health', 'care', 'sciences', 'jikei', 'institute']
# ['waseda', 'university']
# ['abra', 'state', 'institute', 'sciences', 'technology']
# ['de', 'la', 'salle', 'university']
# ['abra', 'state', 'institute', 'sciences', 'technology']
# ['university', 'philippines']
# ['abra', 'state', 'institute', 'sciences', 'technology']
# ['university', 'philippines']
# ['hirosaki', 'university', 'health', 'welfare']
# ['meiji', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['meiji', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['kyoto', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['university', 'tsukuba']
# ['hirosaki', 'university', 'health', 'welfare']
# ['international', 'university', 'japan']
# ['hirosaki', 'university', 'health', 'welfare']
# ['meiji', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['meiji', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['kwansei', 'gakuin', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['kyoto', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['chuo', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['meiji', 'university']
# ['hirosaki', 'university', 'health', 'welfare']
# ['waseda', 'university']
# ['national', 'university', 'canete']
# ['university', 'del', 'pacifico']
# ['san', 'lorenzo', 'dema', 'ala', 'academy']
# ['de', 'la', 'salle', 'university']
# ['san', 'lorenzo', 'dema', 'ala', 'academy']
# ['university', 'philippines']
# ['san', 'lorenzo', 'dema', 'ala', 'academy']
# ['university', 'philippines']
# ['maria', 'auxiliadora', 'university']
# ['university', 'del', 'pacifico']
# ['university', 'engineering', 'technology']
# ['university', 'del', 'pacifico']
# ['maritime', 'university', 'peru']
# ['university', 'del', 'pacifico']
# ['mexican', 'academy', 'fiscal', 'research']
# ['university', 'de', 'las', 'americas', 'puebla']
# ['mexican', 'academy', 'fiscal', 'research']
# ['university', 'autonoma', 'del', 'estado', 'de', 'mexico']
# ['sou', 'rn', 'peruvian', 'university', 'cusco']
# ['university', 'del', 'pacifico']
# ['national', 'university', 'jaen']
# ['university', 'del', 'pacifico']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['vrije', 'university', 'brussel']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['university', 'antwerp']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ghent', 'university']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ku', 'leuven']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['vlerick', 'business', 'school']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ghent', 'university']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ghent', 'university']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ghent', 'university']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ku', 'leuven']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['university', 'antwerp']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['vlerick', 'business', 'school']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['university', 'antwerp/', 'antwerp', 'management', 'school']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['vrije', 'university', 'brussel']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['vrije', 'university', 'brussel']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ghent', 'university']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['university', 'libre', 'de', 'bruxelles']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ulb', 'solvay', 'brussels', 'school;', 'cermi']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['katholieke', 'university', 'leuven']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['louvain', 'school', 'management']
# ['academie', 'royale', 'des', 'beaux', 'arts', 'de', 'la', 'ville', 'de', 'bruxelles', 'ecole', 'superieure', 'des', 'arts']
# ['ku', 'leuven']
# ['abada', 'college']
# ['de', 'la', 'salle', 'university']
# ['abada', 'college']
# ['university', 'philippines']
# ['abada', 'college']
# ['university', 'philippines']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['meiji', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['meiji', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['kyoto', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['university', 'tsukuba']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['international', 'university', 'japan']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['meiji', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['meiji', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['kwansei', 'gakuin', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['kyoto', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['chuo', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['meiji', 'university']
# ['hollywood', 'graduate', 'school', 'beauty', 'business']
# ['waseda', 'university']
# ['japan', 'professional', 'school', 'education']
# ['meiji', 'university']
# ['japan', 'professional', 'school', 'education']
# ['meiji', 'university']
# ['japan', 'professional', 'school', 'education']
# ['kyoto', 'university']
# ['japan', 'professional', 'school', 'education']
# ['university', 'tsukuba']
# ['japan', 'professional', 'school', 'education']
# ['international', 'university', 'japan']
# ['japan', 'professional', 'school', 'education']
# ['meiji', 'university']
# ['japan', 'professional', 'school', 'education']
# ['meiji', 'university']
# ['japan', 'professional', 'school', 'education']
# ['kwansei', 'gakuin', 'university']
# ['japan', 'professional', 'school', 'education']
# ['kyoto', 'university']
# ['japan', 'professional', 'school', 'education']
# ['chuo', 'university']
# ['japan', 'professional', 'school', 'education']
# ['meiji', 'university']
# ['japan', 'professional', 'school', 'education']
# ['waseda', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['meiji', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['meiji', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['kyoto', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['university', 'tsukuba']
# ['japan', 'university', 'health', 'sciences']
# ['international', 'university', 'japan']
# ['japan', 'university', 'health', 'sciences']
# ['meiji', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['meiji', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['kwansei', 'gakuin', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['kyoto', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['chuo', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['meiji', 'university']
# ['japan', 'university', 'health', 'sciences']
# ['waseda', 'university']
# ['sise', 'private', 'university']
# ['university', 'del', 'pacifico']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cattolica', 'del', 'sacro', 'cuore']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'catania']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'naples', 'par', 'nope']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'padova']
# ['brera', 'academy', 'fine', 'art']
# ['politecnico', 'di', 'milano']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'florence']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cagliari']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['luiss', 'guido', 'carli', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university', '/', 'sda', 'bocconi']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'bologna']
# ['brera', 'academy', 'fine', 'art']
# ['luiss', 'guido', 'carli', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cagliari']
# ['brera', 'academy', 'fine', 'art']
# ['tor', 'vergata', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'bologna']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'padua']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'messina']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['politecnico', 'di', 'milano']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cattolica', 'del', 'sacro', 'cuore']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'milan']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'modena', 'and', 'reggio', 'emilia']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cattolica', 'del', 'sacro', 'cuore', 'milano']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'calabria']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'cagliari']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'bergamo']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'bologna']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'bologna']
# ['brera', 'academy', 'fine', 'art']
# ['bocconi', 'university', '/', 'sda', 'bocconi']
# ['brera', 'academy', 'fine', 'art']
# ['university', 'ca', 'foscari', 'venice']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['kyoto', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['university', 'tsukuba']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['international', 'university', 'japan']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['kwansei', 'gakuin', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['kyoto', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['chuo', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'nursing', 'health', 'sciences']
# ['waseda', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['kyoto', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['university', 'tsukuba']
# ['kansai', 'university', 'welfare', 'sciences']
# ['international', 'university', 'japan']
# ['kansai', 'university', 'welfare', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['kwansei', 'gakuin', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['kyoto', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['chuo', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['meiji', 'university']
# ['kansai', 'university', 'welfare', 'sciences']
# ['waseda', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['meiji', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['meiji', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['kyoto', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['university', 'tsukuba']
# ['kinki', 'health', 'welfare', 'university']
# ['international', 'university', 'japan']
# ['kinki', 'health', 'welfare', 'university']
# ['meiji', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['meiji', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['kwansei', 'gakuin', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['kyoto', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['chuo', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['meiji', 'university']
# ['kinki', 'health', 'welfare', 'university']
# ['waseda', 'university']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['management', 'development', 'institute']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'bangalore']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'kozhikode']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'technology', 'delhi']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'calcutta']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'indore']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['management', 'development', 'institute']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'technology', 'bombay']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'bangalore']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'bangalore']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'lucknow']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['tata', 'institute', 'social', 'sciences']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'bangalore']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['indian', 'institute', 'management', 'udaipur']
# ['acharya', 'n.g.', 'ranga', 'agricultural', 'university']
# ['wipro']
# ['kyoto', 'college', 'arts', 'crafts']
# ['meiji', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['meiji', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['kyoto', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['university', 'tsukuba']
# ['kyoto', 'college', 'arts', 'crafts']
# ['international', 'university', 'japan']
# ['kyoto', 'college', 'arts', 'crafts']
# ['meiji', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['meiji', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['kwansei', 'gakuin', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['kyoto', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['chuo', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['meiji', 'university']
# ['kyoto', 'college', 'arts', 'crafts']
# ['waseda', 'university']
# ['acibadem', 'university']
# ['bahcesehir', 'university']
# ['acibadem', 'university']
# ['istanbul', 'bilgi', 'university']
# ['acibadem', 'university']
# ['istanbul', 'arel', 'university']
# ['acibadem', 'university']
# ['ege', 'university', 'science', 'and', 'technology', 'centre']
# ['acibadem', 'university']
# ['toros', 'university']
# ['acibadem', 'university']
# ['sabanci', 'university']
# ['kyoto', 'kacho', 'university']
# ['meiji', 'university']
# ['kyoto', 'kacho', 'university']
# ['meiji', 'university']
# ['kyoto', 'kacho', 'university']
# ['kyoto', 'university']
# ['kyoto', 'kacho', 'university']
# ['university', 'tsukuba']
# ['kyoto', 'kacho', 'university']
# ['international', 'university', 'japan']
# ['kyoto', 'kacho', 'university']
# ['meiji', 'university']
# ['kyoto', 'kacho', 'university']
# ['meiji', 'university']
# ['kyoto', 'kacho', 'university']
# ['kwansei', 'gakuin', 'university']
# ['kyoto', 'kacho', 'university']
# ['kyoto', 'university']
# ['kyoto', 'kacho', 'university']
# ['chuo', 'university']
# ['kyoto', 'kacho', 'university']
# ['meiji', 'university']
# ['kyoto', 'kacho', 'university']
# ['waseda', 'university']
# ['acmcl', 'college']
# ['de', 'la', 'salle', 'university']
# ['acmcl', 'college']
# ['university', 'philippines']
# ['acmcl', 'college']
# ['university', 'philippines']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['management', 'development', 'institute']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'bangalore']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'kozhikode']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'technology', 'delhi']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'calcutta']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'indore']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['management', 'development', 'institute']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'ahmedabad']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'technology', 'bombay']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'bangalore']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'bangalore']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'lucknow']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['tata', 'institute', 'social', 'sciences']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'bangalore']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['indian', 'institute', 'management', 'udaipur']
# ['indian', 'institute', 'science', 'education', 'research', 'mohali']
# ['wipro']
# ['hokuriku', 'gakuin', 'university']
# ['meiji', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['meiji', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['kyoto', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['university', 'tsukuba']
# ['hokuriku', 'gakuin', 'university']
# ['international', 'university', 'japan']
# ['hokuriku', 'gakuin', 'university']
# ['meiji', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['meiji', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['kwansei', 'gakuin', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['kyoto', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['chuo', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['meiji', 'university']
# ['hokuriku', 'gakuin', 'university']
# ['waseda', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['meiji', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['meiji', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['kyoto', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['university', 'tsukuba']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['international', 'university', 'japan']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['meiji', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['meiji', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['kwansei', 'gakuin', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['kyoto', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['chuo', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['meiji', 'university']
# ['morinomiya', 'university', 'medical', 'sciences']
# ['waseda', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['meiji', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['meiji', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['kyoto', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['university', 'tsukuba']
# ['hosen', 'college', 'childhood', 'education']
# ['international', 'university', 'japan']
# ['hosen', 'college', 'childhood', 'education']
# ['meiji', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['meiji', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['kwansei', 'gakuin', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['kyoto', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['chuo', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['meiji', 'university']
# ['hosen', 'college', 'childhood', 'education']
# ['waseda', 'university']
# ['acsi', 'business', 'computer', 'school']
# ['de', 'la', 'salle', 'university']
# ['acsi', 'business', 'computer', 'school']
# ['university', 'philippines']
# ['acsi', 'business', 'computer', 'school']
# ['university', 'philippines']
# ['nihon', 'institute', 'medical', 'science']
# ['meiji', 'university']
# ['nihon', 'institute', 'medical', 'science']
# ['meiji', 'university']
# ['nihon', 'institute', 'medical', 'science']
# ['kyoto', 'university']
# ['nihon', 'institute', 'medical', 'science']
# ['university', 'tsukuba']
# ['nihon', 'institute', 'medical', 'science']
# ['international', 'university', 'japan']
# ['nihon', 'institute', 'medical', 'science']
# ['meiji', 'university']
# ['nihon', 'institute', 'medical', 'science']
# ...
# ['otto', 'von', 'guericke', 'university', 'magdeburg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['ruhr', 'university', 'bochum']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'dresden']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'applied', 'management']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'passau']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['tum', 'school', 'management']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['social', 'science', 'research', 'center', 'berlin', 'wzb']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['johannes', 'gutenberg', 'university', 'mainz']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['federal', 'institute', 'for', 'occupational', 'safety', 'and', 'health']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'darmstadt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'wuppertal', '/', 'jackstadt', 'center', 'entrepreneurship', 'and', 'innovation', 'research']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['friedrich', 'alexander', 'university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'bonn']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'darmstadt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['ebs', 'business', 'school']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['johann', 'wolfgang', 'goe', 'university', 'frankfurt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'munchen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'bayreuth']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technical', 'university', 'munich']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['hhl', 'leipzig', 'graduate', 'school', 'management']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technical', 'university', 'munich']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['german', 'graduate', 'school', 'management', 'law', 'ggs']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'darmstadt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['deloitte', 'consulting']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['tu', 'dortmund', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['reutlingen', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['konstanz', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['wzb', 'berlin', 'social', 'science', 'center']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'bamberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'freiburg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['helmut', 'schmidt', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'bamberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'hannover']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'tuebingen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['leuphana', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'zurich']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['european', 'university', 'viadrina']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'munchen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['friedrich', 'alexander', 'university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technical', 'university', 'kaiserslautern']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'munich']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'gottingen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['whu', 'otto', 'beisheim', 'school', 'management']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'mannheim']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['friedrich', 'alexander', 'university', 'erlangen', 'nuremberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['freie', 'university', 'berlin']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['rwth', 'aachen', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['esmt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['rwth', 'aachen', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'goettingen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['tu', 'dortmund', 'university']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'mannheim']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'cologne']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['lmu', 'munich']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['technische', 'university', 'bergakademie', 'freiberg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['whu', 'otto', 'beisheim', 'school', 'management']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'bayreuth']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['university', 'passau']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['justus', 'liebig', 'university', 'giessen']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['johann', 'wolfgang', 'goe', 'university', 'frankfurt']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['tu', 'kaiserslautern']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['otto', 'von', 'guericke', 'university', 'magdeburg']
# ['alanus', 'university', 'arts', 'social', 'sciences']
# ['mannheim', 'university']
# ['research', 'centre', 'slovenian', 'academy', 'sciences', 'arts']
# ['university', 'ljubljana', 'faculty', 'economics']
# ['sbs', 'swiss', 'business', 'school']
# ['imd']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'geneva']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'lausanne', 'hec', 'lausanne']
# ['sbs', 'swiss', 'business', 'school']
# ['ecole', 'hoteliere', 'de', 'lausanne']
# ['sbs', 'swiss', 'business', 'school']
# ['ecole', 'hoteliere', 'de', 'lausanne']
# ['sbs', 'swiss', 'business', 'school']
# ['eth', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'lugano']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'lausanne']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'lugano']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'lausanne']
# ['sbs', 'swiss', 'business', 'school']
# ['eth', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['haute', 'ecole', 'de', 'gestion', 'fribourg']
# ['sbs', 'swiss', 'business', 'school']
# ['eth', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['eth', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'st.', 'gallen']
# ['sbs', 'swiss', 'business', 'school']
# ['imd']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'zurich']
# ['sbs', 'swiss', 'business', 'school']
# ['university', 'geneva']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['university', 'nordland']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['university', 'witten/herdecke']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['norwegian', 'defence', 'university', 'college']
# ['nordland', 'research', 'institute']
# ['norwegian', 'defence', 'university', 'college']
# ['deloitte']
# ['norwegian', 'defence', 'university', 'college']
# ['norwegian', 'school', 'economics']
# ['norwegian', 'defence', 'university', 'college']
# ['university', 'nordland']
# ['norwegian', 'defence', 'university', 'college']
# ['norwegian', 'school', 'economics']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['university', 'nordland']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['university', 'witten/herdecke']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['bi', 'norwegian', 'business', 'school']
# ['diakonova', 'university', 'college']
# ['nordland', 'research', 'institute']
# ['diakonova', 'university', 'college']
# ['deloitte']
# ['diakonova', 'university', 'college']
# ['norwegian', 'school', 'economics']
# ['diakonova', 'university', 'college']
# ['university', 'nordland']
# ['diakonova', 'university', 'college']
# ['norwegian', 'school', 'economics']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['university', 'nordland']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['university', 'witten/herdecke']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['bi', 'norwegian', 'business', 'school']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['nordland', 'research', 'institute']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['deloitte']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['norwegian', 'school', 'economics']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['university', 'nordland']
# ['westerdals', 'oslo', 'school', 'arts', 'communication', 'technology']
# ['norwegian', 'school', 'economics']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['nova', 'university', 'lisbon']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['catholic', 'university', 'portugal']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['iseg', 'lisboa', 'school', 'economics', 'and', 'management']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['iscte', 'lisbon', 'university', 'institute']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['reis', 'center', 'llc', 'scientific', 'research', 'management']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['catholic', 'university', 'portugal']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['nova', 'university', 'lisbon']
# ['jean', 'piaget', 'school', 'education', 'vila', 'nova', 'de', 'gaia']
# ['nova', 'school', 'business', 'and', 'economics']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['nova', 'university', 'lisbon']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['catholic', 'university', 'portugal']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['iseg', 'lisboa', 'school', 'economics', 'and', 'management']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['iscte', 'lisbon', 'university', 'institute']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['reis', 'center', 'llc', 'scientific', 'research', 'management']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['catholic', 'university', 'portugal']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['nova', 'university', 'lisbon']
# ['jean', 'piaget', 'school', 'health', 'viseu']
# ['nova', 'school', 'business', 'and', 'economics']
# ['cooperative', 'polytechnic', 'university', 'education']
# ['catholic', 'university', 'portugal']
# ['cooperative', 'polytechnic', 'university', 'education']
# ['reis', 'center', 'llc', 'scientific', 'research', 'management']
# ['cooperative', 'polytechnic', 'university', 'education']
# ['nova', 'university', 'lisbon']
# ['alemarz', 'school', 'science', 'technology']
# ['de', 'la', 'salle', 'university']
# ['alemarz', 'school', 'science', 'technology']
# ['university', 'philippines']
# ['alemarz', 'school', 'science', 'technology']
# ['university', 'philippines']
# ['stockholm', 'university', 'arts']
# ['jonkoping', 'international', 'business', 'school']
# ['stockholm', 'university', 'arts']
# ['jonkoping', 'international', 'business', 'school']
# ['stockholm', 'university', 'arts']
# ['linkoping', 'university']
# ['stockholm', 'university', 'arts']
# ['stockholm', 'school', 'economics']
# ['stockholm', 'university', 'arts']
# ['university', 'go', 'nburg']
# ['stockholm', 'university', 'arts']
# ['stockholm', 'school', 'economics']
# ['stockholm', 'university', 'arts']
# ['lund', 'university']
# ['stockholm', 'university', 'arts']
# ['linkoping', 'university']
# ['stockholm', 'university', 'arts']
# ['stockholm', 'school', 'economics']
# ['stockholm', 'university', 'arts']
# ['stockholm', 'school', 'economics']
# ['stockholm', 'university', 'arts']
# ['stockholm', 'university']
# ['stockholm', 'university', 'arts']
# ['jonkoping', 'international', 'business', 'school']

# %%
C.head(n = 50000)
# Out:
#          _id  ltable_person_id  rtable_a_id  \
# 0          0             46555        13931
# 1          1             46555        17165
# 2          2             46555        19344
# 3          3             46555         4784
# 4          4             46555        17309
# 5          5             46555         3204
# 6          6             46555        17285
# 7          7             46555        17362
# 8          8             46555         3215
# 9          9             46555        17564
# 10        10             46555        17386
# 11        11             46555         3212
# 12        12             46555        17460
# 13        13             46555         4591
# 14        14             46555        17858
# 15        15             46555        19324
# 16        16             46555         3206
# 17        17             46555         4564
# 18        18             46555        19359
# 19        19             46555        17387
# 20        20             46555         3202
# 21        21             46555         3210
# 22        22             46555         4783
# 23        23             46555        17548
# 24        24             46555        17758
# 25        25             46555        17622
# 26        26             46555        17133
# 27        27             46555        17412
# 28        28             46555        17265
# 29        29             46559        16988
# ...      ...               ...          ...
# 43749  43749             57204         4145
# 43750  43750             57204        19641
# 43751  43751             57204         7898
# 43752  43752             57204         4095
# 43753  43753             57204        19642
# 43754  43754             57204         4524
# 43755  43755             57204         4053
# 43756  43756             57204        23086
# 43757  43757             57204         4823
# 43758  43758             57204         4010
# 43759  43759             57204         7905
# 43760  43760             57204         4507
# 43761  43761             57204         4132
# 43762  43762             57204        23099
# 43763  43763             57204         4380
# 43764  43764             57204         4260
# 43765  43765             57204        19638
# 43766  43766             57204         6808
# 43767  43767             57204        19743
# 43768  43768             57204         8000
# 43769  43769             57204         4339
# 43770  43770             57204        19575
# 43771  43771             57204         4171
# 43772  43772             57204         4178
# 43773  43773             57204         4102
# 43774  43774             57204         4163
# 43775  43775             57204        19799
# 43776  43776             57204         6786
# 43777  43777             57204         4240
# 43778  43778             57204         4050
#
#                              ltable_a_name ltable_a_country ltable_a_city  \
# 0                  university de barcelona            spain     barcelona
# 1                  university de barcelona            spain     barcelona
# 2                  university de barcelona            spain     barcelona
# 3                  university de barcelona            spain     barcelona
# 4                  university de barcelona            spain     barcelona
# 5                  university de barcelona            spain     barcelona
# 6                  university de barcelona            spain     barcelona
# 7                  university de barcelona            spain     barcelona
# 8                  university de barcelona            spain     barcelona
# 9                  university de barcelona            spain     barcelona
# 10                 university de barcelona            spain     barcelona
# 11                 university de barcelona            spain     barcelona
# 12                 university de barcelona            spain     barcelona
# 13                 university de barcelona            spain     barcelona
# 14                 university de barcelona            spain     barcelona
# 15                 university de barcelona            spain     barcelona
# 16                 university de barcelona            spain     barcelona
# 17                 university de barcelona            spain     barcelona
# 18                 university de barcelona            spain     barcelona
# 19                 university de barcelona            spain     barcelona
# 20                 university de barcelona            spain     barcelona
# 21                 university de barcelona            spain     barcelona
# 22                 university de barcelona            spain     barcelona
# 23                 university de barcelona            spain     barcelona
# 24                 university de barcelona            spain     barcelona
# 25                 university de barcelona            spain     barcelona
# 26                 university de barcelona            spain     barcelona
# 27                 university de barcelona            spain     barcelona
# 28                 university de barcelona            spain     barcelona
# 29     makerere university business school           uganda       kampala
# ...                                    ...              ...           ...
# 43749     centre d economie de la sorbonne           france         paris
# 43750     centre d economie de la sorbonne           france         paris
# 43751     centre d economie de la sorbonne           france         paris
# 43752     centre d economie de la sorbonne           france         paris
# 43753     centre d economie de la sorbonne           france         paris
# 43754     centre d economie de la sorbonne           france         paris
# 43755     centre d economie de la sorbonne           france         paris
# 43756     centre d economie de la sorbonne           france         paris
# 43757     centre d economie de la sorbonne           france         paris
# 43758     centre d economie de la sorbonne           france         paris
# 43759     centre d economie de la sorbonne           france         paris
# 43760     centre d economie de la sorbonne           france         paris
# 43761     centre d economie de la sorbonne           france         paris
# 43762     centre d economie de la sorbonne           france         paris
# 43763     centre d economie de la sorbonne           france         paris
# 43764     centre d economie de la sorbonne           france         paris
# 43765     centre d economie de la sorbonne           france         paris
# 43766     centre d economie de la sorbonne           france         paris
# 43767     centre d economie de la sorbonne           france         paris
# 43768     centre d economie de la sorbonne           france         paris
# 43769     centre d economie de la sorbonne           france         paris
# 43770     centre d economie de la sorbonne           france         paris
# 43771     centre d economie de la sorbonne           france         paris
# 43772     centre d economie de la sorbonne           france         paris
# 43773     centre d economie de la sorbonne           france         paris
# 43774     centre d economie de la sorbonne           france         paris
# 43775     centre d economie de la sorbonne           france         paris
# 43776     centre d economie de la sorbonne           france         paris
# 43777     centre d economie de la sorbonne           france         paris
# 43778     centre d economie de la sorbonne           france         paris
#
#         ltable_a_prov ltable_a_email_server  \
# 0                 NaN                 gmail
# 1                 NaN                 gmail
# 2                 NaN                 gmail
# 3                 NaN                 gmail
# 4                 NaN                 gmail
# 5                 NaN                 gmail
# 6                 NaN                 gmail
# 7                 NaN                 gmail
# 8                 NaN                 gmail
# 9                 NaN                 gmail
# 10                NaN                 gmail
# 11                NaN                 gmail
# 12                NaN                 gmail
# 13                NaN                 gmail
# 14                NaN                 gmail
# 15                NaN                 gmail
# 16                NaN                 gmail
# 17                NaN                 gmail
# 18                NaN                 gmail
# 19                NaN                 gmail
# 20                NaN                 gmail
# 21                NaN                 gmail
# 22                NaN                 gmail
# 23                NaN                 gmail
# 24                NaN                 gmail
# 25                NaN                 gmail
# 26                NaN                 gmail
# 27                NaN                 gmail
# 28                NaN                 gmail
# 29                NaN                  mubs
# ...               ...                   ...
# 43749  paris cedex 13           univ-paris1
# 43750  paris cedex 13           univ-paris1
# 43751  paris cedex 13           univ-paris1
# 43752  paris cedex 13           univ-paris1
# 43753  paris cedex 13           univ-paris1
# 43754  paris cedex 13           univ-paris1
# 43755  paris cedex 13           univ-paris1
# 43756  paris cedex 13           univ-paris1
# 43757  paris cedex 13           univ-paris1
# 43758  paris cedex 13           univ-paris1
# 43759  paris cedex 13           univ-paris1
# 43760  paris cedex 13           univ-paris1
# 43761  paris cedex 13           univ-paris1
# 43762  paris cedex 13           univ-paris1
# 43763  paris cedex 13           univ-paris1
# 43764  paris cedex 13           univ-paris1
# 43765  paris cedex 13           univ-paris1
# 43766  paris cedex 13           univ-paris1
# 43767  paris cedex 13           univ-paris1
# 43768  paris cedex 13           univ-paris1
# 43769  paris cedex 13           univ-paris1
# 43770  paris cedex 13           univ-paris1
# 43771  paris cedex 13           univ-paris1
# 43772  paris cedex 13           univ-paris1
# 43773  paris cedex 13           univ-paris1
# 43774  paris cedex 13           univ-paris1
# 43775  paris cedex 13           univ-paris1
# 43776  paris cedex 13           univ-paris1
# 43777  paris cedex 13           univ-paris1
# 43778  paris cedex 13           univ-paris1
#
#                                                                    rtable_a_name  \
# 0                                               royal school dramatic art madrid
# 1                                                             nebrija university
# 2                                                             jaume i university
# 3                                                   school dramatic art valencia
# 4                              saint vincent martyr catholic university valencia
# 5                                      rafael orozco music conservatoire cordoba
# 6                                                      catholic university avila
# 7                                                  complutense university madrid
# 8                                       oscar espla music conservatoire alicante
# 9                                                              university oviedo
# 10                                                             university alcala
# 11                                  joaquin rodrigo music conservatoire valencia
# 12                                                            university granada
# 13                                                        music school catalonia
# 14                                            international university andalusia
# 15                                                             university lleida
# 16                                                    music conservatoire malaga
# 17                                               school art conservation galicia
# 18                           universitat politecnica de catalunya barcelona tech
# 19                                                           university alicante
# 20                                                    music conservatoire aragon
# 21                                                      music conservatoire vigo
# 22                                                   school dramatic art seville
# 23                                                            university navarra
# 24                                                    european university madrid
# 25                                                         university valladolid
# 26                                                 alfonso x el sabio university
# 27                                                          university cantabria
# 28                                               cardinal herrera ceu university
# 29                                                 uganda pentecostal university
# ...                                                                          ...
# 43749                                                  nancy national art school
# 43750                                                        rennes 1 university
# 43751                                                  catholic university paris
# 43752                                             national school civil aviation
# 43753                                                           university rouen
# 43754                                                 esc rennes business school
# 43755                                                   european business school
# 43756              aix marseilles university construction public works institute
# 43757                                                                esiee paris
# 43758                                            school agricultural engineering
# 43759                  institute political studies grenoble sciences po grenoble
# 43760                        university technology troyes epf school engineering
# 43761                                      normandy national school architecture
# 43762  university franche comte national higher school mechanics microtechnology
# 43763                                                      edhec business school
# 43764                lyon 1 university lyon school chemistry physics electronics
# 43765                                            university picardie jules verne
# 43766                                                                    esc pau
# 43767                                                          lyon 3 university
# 43768                                          icd international business school
# 43769                                                    estaca levallois perret
# 43770                                            university corsica pascal paoli
# 43771                               national school library information sciences
# 43772                                                      ensa dijon art design
# 43773                        school statistics economic administration paristech
# 43774                                               national school applied arts
# 43775                                  paris west nanterre la defense university
# 43776                                                 grenoble school management
# 43777                                           le havre rouen school art design
# 43778                                             french army engineering school
#
#       rtable_a_country            rtable_a_city rtable_a_prov  \
# 0                spain                   madrid           NaN
# 1                spain      hoyos de manzanares        Madrid
# 2                spain    castellon de la plana     Castellon
# 3                spain                 valencia           NaN
# 4                spain                 valencia           NaN
# 5                spain                  cordoba           NaN
# 6                spain                    avila           NaN
# 7                spain                   madrid           NaN
# 8                spain                 alicante           NaN
# 9                spain                   oviedo      Asturias
# 10               spain        alcala de henares        Madrid
# 11               spain                 valencia           NaN
# 12               spain                  granada           NaN
# 13               spain                barcelona           NaN
# 14               spain                  sevilla           NaN
# 15               spain                   lleida           NaN
# 16               spain                   malaga           NaN
# 17               spain               pontevedra           NaN
# 18               spain                barcelona           NaN
# 19               spain   san vicent del raspeig      Alicante
# 20               spain                 zaragoza           NaN
# 21               spain                     vigo           NaN
# 22               spain                  sevilla           NaN
# 23               spain                 pamplona       Navarra
# 24               spain     villaviciosa de odon        Madrid
# 25               spain               valladolid           NaN
# 26               spain  villanueva de la canada        Madrid
# 27               spain                santander     Cantabria
# 28               spain                  moncada      Valencia
# 29              uganda              fort portal           NaN
# ...                ...                      ...           ...
# 43749           france                    nancy         Cedex
# 43750           france                   rennes         Cedex
# 43751           france                    paris      Cedex 06
# 43752           france                 toulouse           NaN
# 43753           france        mont saint aignan         Cedex
# 43754           france                   rennes           NaN
# 43755           france                    paris           NaN
# 43756           france                marseille      cedex 13
# 43757           france           noisy le grand         Cedex
# 43758           france        mont saint aignan         Cedex
# 43759           france     saint martin d heres           NaN
# 43760           france                   sceaux           NaN
# 43761           france                 darnetal           NaN
# 43762           france                 besancon         cedex
# 43763           france                  roubaix       Cedex 1
# 43764           france             villeurbanne         Cedex
# 43765           france                   amiens           NaN
# 43766           france                      pau           NaN
# 43767           france                     lyon           NaN
# 43768           france                    paris           NaN
# 43769           france         levallois perret         Cedex
# 43770           france                    corte         Cedex
# 43771           france             villeurbanne         Cedex
# 43772           france                    dijon         Cedex
# 43773           france                 malakoff         Cedex
# 43774           france                    paris           NaN
# 43775           france                 nanterre         Cedex
# 43776           france                 grenoble      Cedex 01
# 43777           france                 le havre           NaN
# 43778           france                   angers           NaN
#
#                                                 rtable_a_web
# 0                                        http://www.resad.es
# 1                                     http://www.nebrija.com
# 2                                          http://www.uji.es
# 3                                http://www.esadvalencia.com
# 4                                          http://www.ucv.es
# 5                                  http://www.csmcordoba.com
# 6                                      http://www.ucavila.es
# 7                                          http://www.ucm.es
# 8                                  http://www.csmalicante.es
# 9                                       http://www.uniovi.es
# 10                                         http://www.uah.es
# 11                                http://www.csmvalencia.es/
# 12                                         http://www.ugr.es
# 13                                      http://www.esmuc.cat
# 14                                        http://www.unia.es
# 15                                         http://www.udl.es
# 16               http://www.conservatoriosuperiormalaga.com/
# 17                       http://www.gradoconservacionbbcc.es
# 18                          http://www.barcelonatech.upc.edu
# 19                                          http://www.ua.es
# 20                                        http://www.csma.es
# 21                  http://www.conservatoriosuperiorvigo.com
# 22                                http://www.esadsevilla.com
# 23                                        http://www.unav.es
# 24                                         http://www.uem.es
# 25                                         http://www.uva.es
# 26                                         http://www.uax.es
# 27                                      http://www.unican.es
# 28                                     http://www.uch.ceu.es
# 29                                          http://upu.ac.ug
# ...                                                      ...
# 43749                               http://www.ensa-nancy.fr
# 43750                             http://www.univ-rennes1.fr
# 43751                                      http://www.icp.fr
# 43752                                     http://www.enac.fr
# 43753                               http://www.univ-rouen.fr
# 43754                               http://www.esc-rennes.fr
# 43755                               http://www.ebs-paris.com
# 43756                                     http://www.isba.fr
# 43757                              http://www.esiee-paris.fr
# 43758                                 http://www.esitpa.org/
# 43759                     http://www.sciencespo-grenoble.fr/
# 43760                                      http://www.epf.fr
# 43761                              http://www.rouen.archi.fr
# 43762                                   http://www.ens2m.fr/
# 43763                                   http://www.edhec.com
# 43764                                      http://www.cpe.fr
# 43765                               http://www.u-picardie.fr
# 43766                                  http://www.esc-pau.fr
# 43767                               http://www.univ-lyon3.fr
# 43768                              http://www.icd-ecoles.com
# 43769                                   http://www.estaca.fr
# 43770                               http://www.univ-corse.fr
# 43771                                   http://www.enssib.fr
# 43772                               http://www.ensa-dijon.fr
# 43773                                    http://www.ensae.fr
# 43774                                 http://www.ensaama.net
# 43775                                http://www.u-paris10.fr
# 43776                             http://www.grenoble-em.com
# 43777                                  http://www.esadhar.fr
# 43778  http://www.esag.terre.defense.gouv.fr/index_esag.html
#
# [43779 rows x 13 columns]

# %%
C.size
# Out:
# 3426683
